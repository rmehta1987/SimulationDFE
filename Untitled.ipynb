# %%
import allel
import numpy as np

# %%
aji_vcf = allel.read_vcf('/home/rahul/PopGen/SimulationSFS/gnomAD_data/gnomad.exomes.r2.1.1.sites.1.vcf.bgz',fields='*')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 aji_vcf = allel.read_vcf('/home/rahul/PopGen/SimulationSFS/gnomAD_data/gnomad.exomes.r2.1.1.sites.1.vcf.bgz',fields='*')
#
# File /usr/local/lib/python3.10/dist-packages/allel/io/vcf_read.py:322, in read_vcf(input, fields, exclude_fields, rename_fields, types, numbers, alt_number, fills, region, tabix, samples, transformers, buffer_size, chunk_length, log)
#     319     it = _chunk_iter_progress(it, log, prefix='[read_vcf]')
#     321 # read all chunks into a list
# --> 322 chunks = [d[0] for d in it]
#     324 if chunks:
#     325
#     326     # setup output
#     327     output = dict()
#
# File /usr/local/lib/python3.10/dist-packages/allel/io/vcf_read.py:322, in <listcomp>(.0)
#     319     it = _chunk_iter_progress(it, log, prefix='[read_vcf]')
#     321 # read all chunks into a list
# ...

# %%
aji_header = allel.read_vcf_headers('/home/rahul/PopGen/SimulationSFS/gnomAD_data/gnomad.exomes.r2.1.1.sites.1.vcf.bgz')

# %%
list(aji_vcf.keys())
# Out:
# ['variants/ALT',
#  'variants/CHROM',
#  'variants/FILTER_PASS',
#  'variants/ID',
#  'variants/POS',
#  'variants/QUAL',
#  'variants/REF']

# %%
vid = aji_vcf['INFO']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 vid = aji_vcf['INFO']
#
# KeyError: 'INFO'

# %%
vid
# Out:
# array(['rs62635282', 'rs1324090652', 'rs1330604035', ..., 'rs762976213',
#        'rs1193754921', 'rs767156546'], dtype=object)

# %%
aji_header
# Out:
# VCFHeaders(headers=['##fileformat=VCFv4.2\n', '##hailversion=0.2.7-fff3c70bdaf7\n', '##FILTER=<ID=AC0,Description="Allele count is zero after filtering out low-confidence genotypes (GQ < 20; DP < 10; and AB < 0.2 for het calls)">\n', '##FILTER=<ID=InbreedingCoeff,Description="InbreedingCoeff < -0.3">\n', '##FILTER=<ID=PASS,Description="Passed all variant filters">\n', '##FILTER=<ID=RF,Description="Failed random forest filtering thresholds of 0.055272738028512555, 0.20641025579497013 (probabilities of being a true positive variant) for SNPs, indels">\n', '##INFO=<ID=AC,Number=A,Type=Integer,Description="Alternate allele count for samples">\n', '##INFO=<ID=AN,Number=1,Type=Integer,Description="Total number of alleles in samples">\n', '##INFO=<ID=AF,Number=A,Type=Float,Description="Alternate allele frequency in samples">\n', '##INFO=<ID=rf_tp_probability,Number=1,Type=Float,Description="Random forest prediction probability for a site being a true variant">\n', '##INFO=<ID=FS,Number=1,Ty
# ...
